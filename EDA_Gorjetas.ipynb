# %% [markdown]
# ## **IMPORTANDO DADOS**

# %%
import pandas as pd

# %%
dados = pd.read_csv('tips.csv')
dados
# Out:
#      total_bill   tip dessert   day    time  size
# 0         16.99  1.01      No   Sun  Dinner     2
# 1         10.34  1.66      No   Sun  Dinner     3
# 2         21.01  3.50      No   Sun  Dinner     3
# 3         23.68  3.31      No   Sun  Dinner     2
# 4         24.59  3.61      No   Sun  Dinner     4
# ..          ...   ...     ...   ...     ...   ...
# 239       29.03  5.92      No   Sat  Dinner     3
# 240       27.18  2.00     Yes   Sat  Dinner     2
# 241       22.67  2.00     Yes   Sat  Dinner     2
# 242       17.82  1.75      No   Sat  Dinner     2
# 243       18.78  3.00      No  Thur  Dinner     2
#
# [244 rows x 6 columns]

# %% [markdown]
# ## **TRADUÇÃO**

# %%
dados.columns
# Out:
# Index(['total_bill', 'tip', 'dessert', 'day', 'time', 'size'], dtype='object')

# %%
renome = {
    'total_bill' : 'valor_da_conta', 
    'tip' : 'gorjetas', 
    'dessert' : 'sobremesa', 
    'day' : 'dia_da_semana', 
    'time' : 'hora_do_dia', 
    'size' : 'total_de_pessoas'
}

# %%
gorjeta = dados.rename(columns = renome)
gorjeta.head()
# Out:
#    valor_da_conta  gorjetas sobremesa dia_da_semana hora_do_dia  \
# 0           16.99      1.01        No           Sun      Dinner
# 1           10.34      1.66        No           Sun      Dinner
# 2           21.01      3.50        No           Sun      Dinner
# 3           23.68      3.31        No           Sun      Dinner
# 4           24.59      3.61        No           Sun      Dinner
#
#    total_de_pessoas
# 0                 2
# 1                 3
# 2                 3
# 3                 2
# 4                 4

# %%
gorjeta.sobremesa.unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
sim_nao = {
    'No' : 'Não', 
    'Yes' : 'Sim'
}

# %%
gorjeta.sobremesa.map(sim_nao)
# Out:
# 0      Não
# 1      Não
# 2      Não
# 3      Não
# 4      Não
#       ...
# 239    Não
# 240    Sim
# 241    Sim
# 242    Não
# 243    Não
# Name: sobremesa, Length: 244, dtype: object

# %%
gorjeta.sobremesa = gorjeta.sobremesa.map(sim_nao)
gorjeta.head(10)
# Out:
#    valor_da_conta  gorjetas sobremesa dia_da_semana hora_do_dia  \
# 0           16.99      1.01       Não           Sun      Dinner
# 1           10.34      1.66       Não           Sun      Dinner
# 2           21.01      3.50       Não           Sun      Dinner
# 3           23.68      3.31       Não           Sun      Dinner
# 4           24.59      3.61       Não           Sun      Dinner
# 5           25.29      4.71       Não           Sun      Dinner
# 6            8.77      2.00       Não           Sun      Dinner
# 7           26.88      3.12       Não           Sun      Dinner
# 8           15.04      1.96       Não           Sun      Dinner
# 9           14.78      3.23       Não           Sun      Dinner
#
#    total_de_pessoas
# 0                 2
# 1                 3
# 2                 3
# 3                 2
# 4                 4
# 5                 4
# 6                 2
# 7                 4
# 8                 2
# 9                 2

# %%
gorjeta.dia_da_semana.unique()
# Out:
# array(['Sun', 'Sat', 'Thur', 'Fri'], dtype=object)

# %%
dias = {
   'Sun': 'Domingo', 
   'Sat' : 'Sábado', 
   'Thur' : 'Quinta', 
   'Fri' : 'Sexta'
}

# %%
gorjeta.dia_da_semana = gorjeta.dia_da_semana.map(dias)
gorjeta.head(1)
# Out:
#    valor_da_conta  gorjetas sobremesa dia_da_semana hora_do_dia  \
# 0           16.99      1.01       Não       Domingo      Dinner
#
#    total_de_pessoas
# 0                 2

# %%
gorjeta.hora_do_dia.unique()
# Out:
# array(['Dinner', 'Lunch'], dtype=object)

# %%
almoco_janta = {
   'Dinner': 'Jantar', 
   'Lunch' : 'Almoço'
}

# %%
gorjeta.hora_do_dia = gorjeta.hora_do_dia.map(almoco_janta)
gorjeta.head(1)
# Out:
#    valor_da_conta  gorjetas sobremesa dia_da_semana hora_do_dia  \
# 0           16.99      1.01       Não       Domingo      Jantar
#
#    total_de_pessoas
# 0                 2

# %%
gorjeta
# Out:
#      valor_da_conta  gorjetas sobremesa dia_da_semana hora_do_dia  \
# 0             16.99      1.01       Não       Domingo      Jantar
# 1             10.34      1.66       Não       Domingo      Jantar
# 2             21.01      3.50       Não       Domingo      Jantar
# 3             23.68      3.31       Não       Domingo      Jantar
# 4             24.59      3.61       Não       Domingo      Jantar
# ..              ...       ...       ...           ...         ...
# 239           29.03      5.92       Não        Sábado      Jantar
# 240           27.18      2.00       Sim        Sábado      Jantar
# 241           22.67      2.00       Sim        Sábado      Jantar
# 242           17.82      1.75       Não        Sábado      Jantar
# 243           18.78      3.00       Não        Quinta      Jantar
#
#      total_de_pessoas
# 0                   2
# 1                   3
# 2                   3
# 3                   2
# 4                   4
# ..                ...
# ...

# %% [markdown]
# ## **IMPORTANDO SEABORNE**

# %%
import seaborn as sns

# %%
# !pip show seaborn
# Out:
# Name: seaborn
# Version: 0.12.0
# Summary: Statistical data visualization
# Home-page:
# Author:
# Author-email: Michael Waskom <mwaskom@gmail.com>
# License:
# Location: c:\users\marlon\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages
# Requires: matplotlib, numpy, pandas
# Required-by:

# %% [markdown]
# ## **ANALISE 1 --> VALOR DA CONTA E GORJETA**

# %%
valor_gorjeta = sns.scatterplot(x ='valor_da_conta', y = 'gorjetas', data= gorjeta)

# %% [markdown]
# **Visualmente o valor da gorjeta aumenta o valor da conta**

# %%
print(f'A base de dados contém {gorjeta.shape[0]} registro')
# Out:
# A base de dados contém 244 registro

# %%
gorjeta.count()
# Out:
# valor_da_conta      244
# gorjetas            244
# sobremesa           244
# dia_da_semana       244
# hora_do_dia         244
# total_de_pessoas    244
# dtype: int64

# %% [markdown]
# ## **Criando uma coluna**

# %%
gorjeta['porcentagem'] = gorjeta['gorjetas'] / gorjeta['valor_da_conta']

# %%
gorjeta.head()
# Out:
#    valor_da_conta  gorjetas sobremesa dia_da_semana hora_do_dia  \
# 0           16.99      1.01       Não       Domingo      Jantar
# 1           10.34      1.66       Não       Domingo      Jantar
# 2           21.01      3.50       Não       Domingo      Jantar
# 3           23.68      3.31       Não       Domingo      Jantar
# 4           24.59      3.61       Não       Domingo      Jantar
#
#    total_de_pessoas  porcentagem
# 0                 2     0.059447
# 1                 3     0.160542
# 2                 3     0.166587
# 3                 2     0.139780
# 4                 4     0.146808

# %%
gorjeta.porcentagem = gorjeta.porcentagem.round(2)
gorjeta.head()
# Out:
#    valor_da_conta  gorjetas sobremesa dia_da_semana hora_do_dia  \
# 0           16.99      1.01       Não       Domingo      Jantar
# 1           10.34      1.66       Não       Domingo      Jantar
# 2           21.01      3.50       Não       Domingo      Jantar
# 3           23.68      3.31       Não       Domingo      Jantar
# 4           24.59      3.61       Não       Domingo      Jantar
#
#    total_de_pessoas  porcentagem
# 0                 2         0.06
# 1                 3         0.16
# 2                 3         0.17
# 3                 2         0.14
# 4                 4         0.15

# %%
porcentegem_conta = sns.scatterplot(x = 'valor_da_conta', y = 'porcentagem', data = gorjeta)

# %% [markdown]
# **Visualmente, O valor da conta não é proporcional a gorjeta**

# %%
porcentagem_conta_linha = sns.relplot( x = 'valor_da_conta', y = 'porcentagem', kind = 'line', data = gorjeta)

# %%
sns.lmplot(x = 'valor_da_conta', y = 'porcentagem', data = gorjeta)

# %%
gorjeta.gorjetas.mean()
# Out:
# 2.99827868852459

# %%
gorjeta.valor_da_conta.std()
# Out:
# 8.902411954856856

# %% [markdown]
# ## ANÁLISE 2 --> SOBREMESA

# %%
gorjeta.head()
# Out:
#    valor_da_conta  gorjetas sobremesa dia_da_semana hora_do_dia  \
# 0           16.99      1.01       Não       Domingo      Jantar
# 1           10.34      1.66       Não       Domingo      Jantar
# 2           21.01      3.50       Não       Domingo      Jantar
# 3           23.68      3.31       Não       Domingo      Jantar
# 4           24.59      3.61       Não       Domingo      Jantar
#
#    total_de_pessoas  porcentagem
# 0                 2         0.06
# 1                 3         0.16
# 2                 3         0.17
# 3                 2         0.14
# 4                 4         0.15

# %%
gorjeta[gorjeta.sobremesa == 'Sim'].describe()
# Out:
#        valor_da_conta   gorjetas  total_de_pessoas  porcentagem
# count       93.000000  93.000000         93.000000    93.000000
# mean        20.756344   3.008710          2.408602     0.163226
# std          9.832154   1.401468          0.810751     0.085060
# min          3.070000   1.000000          1.000000     0.040000
# 25%         13.420000   2.000000          2.000000     0.110000
# 50%         17.920000   3.000000          2.000000     0.150000
# 75%         26.860000   3.680000          3.000000     0.200000
# max         50.810000  10.000000          5.000000     0.710000

# %%
gorjeta[gorjeta.sobremesa == 'Não'].describe()
# Out:
#        valor_da_conta    gorjetas  total_de_pessoas  porcentagem
# count      151.000000  151.000000        151.000000   151.000000
# mean        19.188278    2.991854          2.668874     0.159536
# std          8.255582    1.377190          1.017984     0.039889
# min          7.250000    1.000000          1.000000     0.060000
# 25%         13.325000    2.000000          2.000000     0.140000
# 50%         17.590000    2.740000          2.000000     0.160000
# 75%         22.755000    3.505000          3.000000     0.185000
# max         48.330000    9.000000          6.000000     0.290000

# %%
sns.catplot(x = 'sobremesa', y = 'gorjetas', data = gorjeta)

# %%
sns.relplot(x = 'valor_da_conta', y = 'gorjetas', hue = 'sobremesa', data = gorjeta)

# %%
sns.relplot(x = 'valor_da_conta', y = 'gorjetas', hue = 'sobremesa', col = 'sobremesa', data = gorjeta)

# %%
sns.lmplot(x = 'valor_da_conta', y = 'gorjetas', col = 'sobremesa', hue = 'sobremesa', data = gorjeta)

# %%
sns.lmplot(x = 'valor_da_conta', y = 'porcentagem', col = 'sobremesa', hue = 'sobremesa', data = gorjeta)

# %%
sns.relplot(x = 'valor_da_conta', y = 'gorjetas', col = 'sobremesa', hue = 'sobremesa', kind = 'line', data = gorjeta)

# %% [markdown]
# **Visualmento, Podemos perceber pelos graficos que existe uma diferença entre quem pediu e quem não pediu sobremesa**

# %% [markdown]
# ## TESTE DE HIPÓTESE

# %% [markdown]
# **Hipotese Nula**

# %%
#!pip install scipy

# %%
from scipy.stats import ranksums

# %% [markdown]
# **temos duas Hipoteses**
# H<sup>null</sup>
# **A distribuição da taxa da gorjeta é a mesma nos dois Grupos**
# H<sup>alt</sup>
# **A distribuição da taxa da gorjeta não é a mesma nos dois Grupos**

# %%
sobremesa =gorjeta.query("sobremesa == 'Sim'").porcentagem

# %%
sem_sobremesa =gorjeta.query("sobremesa == 'Não'").porcentagem

# %%
z, p_value = ranksums(sobremesa, sem_sobremesa)
print(z)
print(p_value)
# Out:
# -0.6331073145314825
# 0.5266635660124415

# %% [markdown]
# ## **Analise Dia da Semana**

# %%
gorjeta.head()
# Out:
#    valor_da_conta  gorjetas sobremesa dia_da_semana hora_do_dia  \
# 0           16.99      1.01       Não       Domingo      Jantar
# 1           10.34      1.66       Não       Domingo      Jantar
# 2           21.01      3.50       Não       Domingo      Jantar
# 3           23.68      3.31       Não       Domingo      Jantar
# 4           24.59      3.61       Não       Domingo      Jantar
#
#    total_de_pessoas  porcentagem
# 0                 2         0.06
# 1                 3         0.16
# 2                 3         0.17
# 3                 2         0.14
# 4                 4         0.15

# %%
gorjeta.dia_da_semana.unique()
# Out:
# array(['Domingo', 'Sábado', 'Quinta', 'Sexta'], dtype=object)

# %%
sns.catplot(x = 'dia_da_semana', y = 'valor_da_conta', hue ='dia_da_semana', data = gorjeta)

# %%
sns.relplot(x = 'valor_da_conta', y = 'gorjetas', hue = 'dia_da_semana', data = gorjeta)

# %%
sns.relplot(x = 'valor_da_conta', y = 'porcentagem', hue = 'dia_da_semana', data = gorjeta)

# %%
sns.relplot(x = 'valor_da_conta', y = 'gorjetas', hue = 'dia_da_semana', col = 'dia_da_semana', data = gorjeta)

# %%
sns.relplot(x = 'valor_da_conta', y = 'porcentagem', hue = 'dia_da_semana', col = 'dia_da_semana', data = gorjeta)

# %%
sns.lmplot(x = 'valor_da_conta', y = 'gorjetas', hue = 'dia_da_semana', col = 'dia_da_semana', data = gorjeta)

# %%
sns.lmplot(x = 'valor_da_conta', y = 'porcentagem', hue = 'dia_da_semana', col = 'dia_da_semana', data = gorjeta)

# %%
media_geral_gorjetas = gorjeta.gorjetas.mean()
media_geral_gorjetas
# Out:
# 2.99827868852459

# %%
media_por_dia1 = gorjeta.groupby(['dia_da_semana']).mean()
media_por_dia1
# Out:
#                valor_da_conta  gorjetas  total_de_pessoas  porcentagem
# dia_da_semana
# Domingo             21.410000  3.255132          2.842105     0.166974
# Quinta              17.682742  2.771452          2.451613     0.161129
# Sexta               17.151579  2.734737          2.105263     0.169474
# Sábado              20.441379  2.993103          2.517241     0.153678

# %%
media_por_dia = gorjeta.groupby(['dia_da_semana']).mean()[['valor_da_conta', 'gorjetas', 'porcentagem']]
media_por_dia
# Out:
#                valor_da_conta  gorjetas  porcentagem
# dia_da_semana
# Domingo             21.410000  3.255132     0.166974
# Quinta              17.682742  2.771452     0.161129
# Sexta               17.151579  2.734737     0.169474
# Sábado              20.441379  2.993103     0.153678

# %%
gorjeta.dia_da_semana.value_counts()
# Out:
# Sábado     87
# Domingo    76
# Quinta     62
# Sexta      19
# Name: dia_da_semana, dtype: int64

# %% [markdown]
# ## **TESTE DE HIPÓTESE**

# %% [markdown]
# **H<sup>null</sup>**
# **A distribuição dop valor da conta é igual no sabado e no domingo**
#
# **H<sup>alt</sup>**
# **A distribuição dop valor da conta não é igual no sabado e no domingo**

# %%
valor_domigo = gorjeta.query('dia_da_semana == "Domingo"').valor_da_conta

# %%
valor_sabado = gorjeta.query('dia_da_semana == "Sábado"').valor_da_conta

# %%
ranksums(valor_domigo, valor_sabado)
# Out:
# RanksumsResult(statistic=0.9198084864360142, pvalue=0.3576728477868443)

# %%
stats, p_valor = ranksums(valor_domigo, valor_sabado)
print(stats)
print(p_valor)
# Out:
# 0.9198084864360142
# 0.3576728477868443

# %% [markdown]
# **H<sup>null</sup>**
# **A distribuição dop valor da conta é igual no sabado e no domingo**

# %% [markdown]
# ## **Análise  Hora do dia**

# %%
gorjeta.head()
# Out:
#    valor_da_conta  gorjetas sobremesa dia_da_semana hora_do_dia  \
# 0           16.99      1.01       Não       Domingo      Jantar
# 1           10.34      1.66       Não       Domingo      Jantar
# 2           21.01      3.50       Não       Domingo      Jantar
# 3           23.68      3.31       Não       Domingo      Jantar
# 4           24.59      3.61       Não       Domingo      Jantar
#
#    total_de_pessoas  porcentagem
# 0                 2         0.06
# 1                 3         0.16
# 2                 3         0.17
# 3                 2         0.14
# 4                 4         0.15

# %%
gorjeta.hora_do_dia.unique()
# Out:
# array(['Jantar', 'Almoço'], dtype=object)

# %%
sns.catplot(x = 'hora_do_dia', y = 'valor_da_conta', hue = 'hora_do_dia', data = gorjeta)

# %%
sns.catplot(x = 'hora_do_dia', y = 'valor_da_conta', hue = 'hora_do_dia',kind = 'swarm', data = gorjeta)

# %%
sns.violinplot(x = 'hora_do_dia', y = 'valor_da_conta', data = gorjeta)
# Out:
# <AxesSubplot:xlabel='hora_do_dia', ylabel='valor_da_conta'>

# %%
sns.boxplot(x = 'hora_do_dia', y = 'valor_da_conta', data = gorjeta)
# Out:
# <AxesSubplot:xlabel='hora_do_dia', ylabel='valor_da_conta'>

# %%
conta_almoco = gorjeta.query('hora_do_dia == "Almoço"').valor_da_conta

# %%
conta_janta = gorjeta.query('hora_do_dia == "Jantar"').valor_da_conta

# %%
sns.displot(conta_almoco)

# %%
sns.displot(conta_almoco, kde = False)

# %%
sns.distplot(conta_janta)
# Out:
# C:\Users\Marlon\AppData\Local\Temp\ipykernel_17000\2884283441.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(conta_janta)
# <AxesSubplot:xlabel='valor_da_conta', ylabel='Density'>

# %%
sns.displot(conta_janta, kde = False)

# %% [markdown]
# ## **Teste de hipotese**

# %% [markdown]
# **H<sup>null</sup>**
# **A distribuição do valor da conta no Jantar é igual a do almoço**
#
# **H<sup>alt</sup>**
# **A distribuição do valor da conta no Jantar não é igual a do almoço**

# %%
gorjeta.groupby(['hora_do_dia']).mean()
# Out:
#              valor_da_conta  gorjetas  total_de_pessoas  porcentagem
# hora_do_dia
# Almoço            17.168676  2.728088          2.411765     0.163971
# Jantar            20.797159  3.102670          2.630682     0.159773

# %%
gorjeta.groupby(['hora_do_dia']).mean()[['valor_da_conta', 'gorjetas', 'porcentagem']]
# Out:
#              valor_da_conta  gorjetas  porcentagem
# hora_do_dia
# Almoço            17.168676  2.728088     0.163971
# Jantar            20.797159  3.102670     0.159773

# %%
ranksums(conta_janta, conta_almoco)
# Out:
# RanksumsResult(statistic=3.2438872807262955, pvalue=0.0011791039723641672)

# %%
porcentagem_almoco = gorjeta.query("hora_do_dia == 'Almoço'").porcentagem

# %%
porcentagem_jantar = gorjeta.query("hora_do_dia == 'Jantar'").porcentagem

# %%
ranksums(porcentagem_almoco, porcentagem_jantar)
# Out:
# RanksumsResult(statistic=1.1258018532735787, pvalue=0.2602493995587126)

# %%
r3 = ranksums(porcentagem_almoco, porcentagem_jantar)
print('O valor do p-value é de {}'.format(r3.pvalue))
# Out:
# O valor do p-value é de 0.2602493995587126
